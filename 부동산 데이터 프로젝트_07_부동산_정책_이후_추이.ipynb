# %% [markdown]
# ### 7 - 부동산 정책 이후 추이

# %% [markdown]
# 문재인 대통령 임기 중 총 29개의 대책이 발표되었다</br> 하지만 이 29개의 대책은 지엽적이거나 작은 추진사항들도 모두 포함되어 있기 때문에</br> <b>주택시장 안정을 위해 발표한 큰 대책인 총 6개만 추려서 분석을 진행<b>
# 1. 6.19 대책 - 주택시장의 안정적 관리를 위한 선별적·맞춤형 대응방안 (2017년 6월 19일)
# 2. 8.2 대책 - 실수요 보호와 단기 투기수요 억제를 통한 주택시장 안정화 방안 (2017년 8월 2일)
# 3. 10.24 대책 - 가계부채 종합대책 (2017년 10월 24일)
# 4. 9.13 대책 - 주택시장 안정대책 (2018년 9월 13일)
# 5. 12.16 대책 - 주택시장 안정화 방안 (2019년 12월 16일)
# 6. 6.17 대책 - 2020년 주거종합계획 (2020년 6월 17일)

# %%
부동산대책 = df.copy()
부동산대책 = 부동산대책.set_index('계약날짜')
부동산대책
# Out:
#                       시군구    구    동          도로명      단지명  건축연도     계약연월  \
# 계약날짜
# 2006-01-03  서울특별시 강남구 역삼동  강남구  역삼동     언주로90길 6  우림루미아트1  2003  2006-01
# 2006-01-06  서울특별시 강남구 개포동  강남구  개포동        선릉로 8      주공2  1982  2006-01
# 2006-01-06  서울특별시 강남구 개포동  강남구  개포동        선릉로 8      주공2  1982  2006-01
# 2006-01-17  서울특별시 강남구 개포동  강남구  개포동        선릉로 8      주공2  1982  2006-01
# 2006-01-18  서울특별시 강남구 개포동  강남구  개포동        선릉로 8      주공2  1982  2006-01
# ...                   ...  ...  ...          ...      ...   ...      ...
# 2021-12-03  서울특별시 서초구 방배동  서초구  방배동   사평대로6길 118   영지아트빌라  1999  2021-12
# 2021-12-17  서울특별시 서초구 잠원동  서초구  잠원동      잠원로 177    청구빌라트  1996  2021-12
# 2021-12-09  서울특별시 서초구 방배동  서초구  방배동   서초대로25길 76    월드빌리지  1999  2021-12
# 2021-12-02  서울특별시 용산구 한남동  용산구  한남동      한남대로 91    나인원한남  2019  2021-12
# 2021-12-13  서울특별시 용산구 한남동  용산구  한남동  유엔빌리지길 80-1    파르크한남  2020  2021-12
#
#             계약연도  계약월  계약일  층  거래금액_억원  전용면적_평  평당금액_억원 구역별          평당_금액대  \
# 계약날짜
# ...

# %%
after_0619 = 부동산대책.loc['2017-06-19' : '2017-09-19'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
after_0619['대책'] = 6.19

after_0802 = 부동산대책.loc['2017-08-02' : '2017-11-02'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
after_0802['대책'] = 8.2

after_1024 = 부동산대책.loc['2017-10-24' : '2018-01-24'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
after_1024['대책'] = 10.24

after_0913 = 부동산대책.loc['2018-09-13' : '2018-12-13'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
after_0913['대책'] = 9.13

after_1216 = 부동산대책.loc['2019-12-16' : '2020-03-16'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
after_1216['대책'] = 12.16

after_0617 = 부동산대책.loc['2020-06-17' : '2020-09-17'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
after_0617['대책'] = 6.17

after = [after_0619, after_0802, after_1024, after_0913, after_1216, after_0617]
after = pd.concat(after,ignore_index = True)

after_group = after.groupby(['구','대책'])['평당금액_억원'].agg({'median','count'}).round(2).reset_index()
after_group.rename(columns = {'median' : 'after_median', 'count' : 'after_count'}, inplace = True)
after_group.drop(columns = {'구','대책'}, inplace = True)
after_group
# Out:
#      after_count  after_median
# 0           1837          0.75
# 1           2762          0.46
# 2           2120          0.47
# 3            475          0.55
# 4           3452          0.49
# ..           ...           ...
# 145         2010          0.15
# 146         1436          0.15
# 147          746          0.18
# 148         1972          0.16
# 149         2052          0.22
#
# [150 rows x 2 columns]

# %%
before_0619 = 부동산대책.loc['2017-03-19' : '2017-06-19'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
before_0619['대책'] = 6.19

before_0802 = 부동산대책.loc['2017-05-02' : '2017-08-02'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
before_0802['대책'] = 8.2

before_1024 = 부동산대책.loc['2017-07-24' : '2017-10-24'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
before_1024['대책'] = 10.24

before_0913 = 부동산대책.loc['2018-06-13' : '2018-09-13'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
before_0913['대책'] = 9.13

before_1216 = 부동산대책.loc['2019-09-16' : '2019-12-16'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
before_1216['대책'] = 12.16

before_0617 = 부동산대책.loc['2020-03-17' : '2020-06-17'][['구','단지명','거래금액_억원','전용면적_평','평당금액_억원','브랜드명']]
before_0617['대책'] = 6.17

before = [before_0619, before_0802, before_1024, before_0913, before_1216, before_0617]
before = pd.concat(before,ignore_index = True)

before_group = before.groupby(['구','대책'])['평당금액_억원'].agg({'median','count'}).round(2).reset_index()
before_group.rename(columns = {'median' : 'before_median', 'count' : 'before_count'}, inplace = True)
before_group
# Out:
#        구     대책  before_count  before_median
# 0    강남구   6.17          1410           0.73
# 1    강남구   6.19          4124           0.46
# 2    강남구   8.20          4949           0.46
# 3    강남구   9.13          2368           0.62
# 4    강남구  10.24          2270           0.47
# ..   ...    ...           ...            ...
# 145  중랑구   6.19          2487           0.15
# 146  중랑구   8.20          2668           0.15
# 147  중랑구   9.13          2268           0.17
# 148  중랑구  10.24          1562           0.16
# 149  중랑구  12.16          1975           0.21
#
# [150 rows x 4 columns]

# %%
after_before_group = pd.concat([before_group, after_group], axis = 1)
after_before_group
# Out:
#        구     대책  before_count  before_median  after_count  after_median
# 0    강남구   6.17          1410           0.73         1837          0.75
# 1    강남구   6.19          4124           0.46         2762          0.46
# 2    강남구   8.20          4949           0.46         2120          0.47
# 3    강남구   9.13          2368           0.62          475          0.55
# 4    강남구  10.24          2270           0.47         3452          0.49
# ..   ...    ...           ...            ...          ...           ...
# 145  중랑구   6.19          2487           0.15         2010          0.15
# 146  중랑구   8.20          2668           0.15         1436          0.15
# 147  중랑구   9.13          2268           0.17          746          0.18
# 148  중랑구  10.24          1562           0.16         1972          0.16
# 149  중랑구  12.16          1975           0.21         2052          0.22
#
# [150 rows x 6 columns]

# %%
after_before_group['변화율_평당가격'] = (after_before_group['after_median'] - after_before_group['before_median']) * 100
after_before_group['변화율_거래량'] = ((after_before_group['after_count'] - after_before_group['before_count']) / after_before_group['before_count']).round(2) * 100

after_before_group
# Out:
#        구     대책  before_count  before_median  after_count  after_median  \
# 0    강남구   6.17          1410           0.73         1837          0.75
# 1    강남구   6.19          4124           0.46         2762          0.46
# 2    강남구   8.20          4949           0.46         2120          0.47
# 3    강남구   9.13          2368           0.62          475          0.55
# 4    강남구  10.24          2270           0.47         3452          0.49
# ..   ...    ...           ...            ...          ...           ...
# 145  중랑구   6.19          2487           0.15         2010          0.15
# 146  중랑구   8.20          2668           0.15         1436          0.15
# 147  중랑구   9.13          2268           0.17          746          0.18
# 148  중랑구  10.24          1562           0.16         1972          0.16
# 149  중랑구  12.16          1975           0.21         2052          0.22
#
#      변화율_평당가격  변화율_거래량
# 0         2.0     30.0
# 1         0.0    -33.0
# 2         1.0    -57.0
# ...

# %% [markdown]
# #### 7-1 6.19 / 8.2 / 10.24 대책

# %% [markdown]
# ##### 7-1-1 평당가격

# %%
# 하락
print(after_before_group.query('대책 == 6.19')["변화율_평당가격"][after_before_group.query('대책 == 6.19')["변화율_평당가격"] < 0].count())

# 유지
print(after_before_group.query('대책 == 6.19')["변화율_평당가격"][after_before_group.query('대책 == 6.19')["변화율_평당가격"] == 0].count())

# 상승
print(after_before_group.query('대책 == 6.19')["변화율_평당가격"][after_before_group.query('대책 == 6.19')["변화율_평당가격"] > 0].count())

# 하락
print(after_before_group.query('대책 == 8.2')["변화율_평당가격"][after_before_group.query('대책 == 8.2')["변화율_평당가격"] < 0].count())

# 유지
print(after_before_group.query('대책 == 8.2')["변화율_평당가격"][after_before_group.query('대책 == 8.2')["변화율_평당가격"] == 0].count())

# 상승
print(after_before_group.query('대책 == 8.2')["변화율_평당가격"][after_before_group.query('대책 == 8.2')["변화율_평당가격"] > 0].count())

# 하락
print(after_before_group.query('대책 == 10.24')["변화율_평당가격"][after_before_group.query('대책 == 10.24')["변화율_평당가격"] < 0].count())

# 유지
print(after_before_group.query('대책 == 10.24')["변화율_평당가격"][after_before_group.query('대책 == 10.24')["변화율_평당가격"] == 0].count())

# 상승
print(after_before_group.query('대책 == 10.24')["변화율_평당가격"][after_before_group.query('대책 == 10.24')["변화율_평당가격"] > 0].count())
# Out:
# 1
# 12
# 12
# 3
# 7
# 15
# 0
# 6
# 19

# %%
labels = ["하락","유지","상승"]

# Create subplots: use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels, values=[1,12,12], name="6.19 대책"),
              1, 1)
fig.add_trace(go.Pie(labels=labels, values=[3,7,15], name="8.2 대책"),
              1, 2)
fig.add_trace(go.Pie(labels=labels, values=[0,6,19], name="10.24 대책"),
              1, 3)


fig.update_traces(hole=.4, hoverinfo="label+value+name")
fig.update_traces(textposition='inside', textinfo='percent+value+label')

fig.update_layout(
    title_text="<b>부동산 대책 이후 평당가격 변화</b>",
    annotations=[dict(text='6.19 대책', x=0.116, y=0.5, font_size=20, showarrow=False),
                 dict(text='8.2 대책', x=0.503, y=0.5, font_size=20, showarrow=False),
                 dict(text='10.24 대책', x=0.89, y=0.5, font_size=20, showarrow=False)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 6.19').sort_values('변화율_평당가격', ascending = False)

fig = px.bar(data, x = '구', y = '변화율_평당가격', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>6.19 부동산 대책 이후 평당가격 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 6.19').sort_values('변화율_평당가격', ascending = False)
data = data.rename(columns = {'구' : 'name'})

fig = px.choropleth_mapbox(data, geojson=state_geo, locations='name', color='변화율_평당가격',
                           color_continuous_scale="bluered", featureidkey="properties.name"
                           ,mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 37.563383, "lon": 126.996039},
                           opacity=0.5)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 8.2').sort_values('변화율_평당가격', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_평당가격', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")  
fig.update_layout(template='simple_white', title_text="<b>8.2 부동산 대책 이후 평당가격 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 8.2').sort_values('변화율_평당가격', ascending = False)
data = data.rename(columns = {'구' : 'name'})

fig = px.choropleth_mapbox(data, geojson=state_geo, locations='name', color='변화율_평당가격',
                           color_continuous_scale="bluered", featureidkey="properties.name"
                           ,mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 37.563383, "lon": 126.996039},
                           opacity=0.5)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 10.24').sort_values('변화율_평당가격', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_평당가격', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>10.24 부동산 대책 이후 평당가격 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 10.24').sort_values('변화율_평당가격', ascending = False)
data = data.rename(columns = {'구' : 'name'})

fig = px.choropleth_mapbox(data, geojson=state_geo, locations='name', color='변화율_평당가격',
                           color_continuous_scale="bluered", featureidkey="properties.name"
                           ,mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 37.563383, "lon": 126.996039},
                           opacity=0.5)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 하락
print(after_before_group.query('대책 == 6.19')["변화율_거래량"][after_before_group.query('대책 == 6.19')["변화율_거래량"] < 0].count())

# 유지
print(after_before_group.query('대책 == 6.19')["변화율_거래량"][after_before_group.query('대책 == 6.19')["변화율_거래량"] == 0].count())

# 상승
print(after_before_group.query('대책 == 6.19')["변화율_거래량"][after_before_group.query('대책 == 6.19')["변화율_거래량"] > 0].count())

# 하락
print(after_before_group.query('대책 == 8.2')["변화율_거래량"][after_before_group.query('대책 == 8.2')["변화율_거래량"] < 0].count())

# 유지
print(after_before_group.query('대책 == 8.2')["변화율_거래량"][after_before_group.query('대책 == 8.2')["변화율_거래량"] == 0].count())

# 상승
print(after_before_group.query('대책 == 8.2')["변화율_거래량"][after_before_group.query('대책 == 8.2')["변화율_거래량"] > 0].count())

# 하락
print(after_before_group.query('대책 == 10.24')["변화율_거래량"][after_before_group.query('대책 == 10.24')["변화율_거래량"] < 0].count())

# 유지
print(after_before_group.query('대책 == 10.24')["변화율_거래량"][after_before_group.query('대책 == 10.24')["변화율_거래량"] == 0].count())

# 상승
print(after_before_group.query('대책 == 10.24')["변화율_거래량"][after_before_group.query('대책 == 10.24')["변화율_거래량"] > 0].count())
# Out:
# 23
# 0
# 2
# 25
# 0
# 0
# 3
# 0
# 22

# %% [markdown]
# ##### 7-1-2 거래량

# %%
labels = ["하락", "유지", "상승"]

# Create subplots: use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels, values=[23,0,2], name="6.19 대책"),
              1, 1)
fig.add_trace(go.Pie(labels=labels, values=[25,0,0], name="8.2 대책"),
              1, 2)
fig.add_trace(go.Pie(labels=labels, values=[3,0,22], name="10.24 대책"),
              1, 3)


fig.update_traces(hole=.4, hoverinfo="label+value+name")
fig.update_traces(textposition='inside', textinfo='percent+value+label')

fig.update_layout(
    title_text="<b>부동산 대책 이후 거래량 변화</b>",
    annotations=[dict(text='6.19 대책 거래량', x=0.107, y=0.5, font_size=15, showarrow=False),
                 dict(text='8.2 대책 거래량', x=0.503, y=0.5, font_size=15, showarrow=False),
                 dict(text='10.24 대책 거래량', x=0.897, y=0.5, font_size=15, showarrow=False)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 6.19').sort_values('변화율_거래량', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_거래량', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>6.19 부동산 대책 이후 거래량 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 6.19').sort_values('변화율_거래량', ascending = False)
data = data.rename(columns = {'구' : 'name'})

fig = px.choropleth_mapbox(data, geojson=state_geo, locations='name', color='변화율_거래량',
                           color_continuous_scale="bluered", featureidkey="properties.name"
                           ,mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 37.563383, "lon": 126.996039},
                           opacity=0.5, range_color = (-1,0))
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 8.2').sort_values('변화율_거래량', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_거래량', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>8.2 부동산 대책 이후 거래량 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 8.2').sort_values('변화율_거래량', ascending = False)
data = data.rename(columns = {'구' : 'name'})

fig = px.choropleth_mapbox(data, geojson=state_geo, locations='name', color='변화율_거래량',
                           color_continuous_scale="bluered", featureidkey="properties.name"
                           ,mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 37.563383, "lon": 126.996039},
                           opacity=0.5, range_color = (-10,0))
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 10.24').sort_values('변화율_거래량', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_거래량', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>10.24 부동산 대책 이후 거래량 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 10.24').sort_values('변화율_거래량', ascending = False)
data = data.rename(columns = {'구' : 'name'})

fig = px.choropleth_mapbox(data, geojson=state_geo, locations='name', color='변화율_거래량',
                           color_continuous_scale="bluered", featureidkey="properties.name"
                           ,mapbox_style="carto-positron",
                           zoom=10, center = {"lat": 37.563383, "lon": 126.996039},
                           opacity=0.5, range_color = (-10,0))
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### 7-2 9.13 / 12.16 / 6.17 대책

# %%
# 하락
print(after_before_group.query('대책 == 9.13')["변화율_평당가격"][after_before_group.query('대책 == 9.13')["변화율_평당가격"] < 0].count())

# 유지
print(after_before_group.query('대책 == 9.13')["변화율_평당가격"][after_before_group.query('대책 == 9.13')["변화율_평당가격"] == 0].count())

# 상승
print(after_before_group.query('대책 == 9.13')["변화율_평당가격"][after_before_group.query('대책 == 9.13')["변화율_평당가격"] > 0].count())

# 하락
print(after_before_group.query('대책 == 12.16')["변화율_평당가격"][after_before_group.query('대책 == 12.16')["변화율_평당가격"] < 0].count())

# 유지
print(after_before_group.query('대책 == 12.16')["변화율_평당가격"][after_before_group.query('대책 == 12.16')["변화율_평당가격"] == 0].count())

# 상승
print(after_before_group.query('대책 == 12.16')["변화율_평당가격"][after_before_group.query('대책 == 12.16')["변화율_평당가격"] > 0].count())

# 하락
print(after_before_group.query('대책 == 6.17')["변화율_평당가격"][after_before_group.query('대책 == 6.17')["변화율_평당가격"] < 0].count())

# 유지
print(after_before_group.query('대책 == 6.17')["변화율_평당가격"][after_before_group.query('대책 == 6.17')["변화율_평당가격"] == 0].count())

# 상승
print(after_before_group.query('대책 == 6.17')["변화율_평당가격"][after_before_group.query('대책 == 6.17')["변화율_평당가격"] > 0].count())
# Out:
# 6
# 2
# 17
# 6
# 7
# 12
# 2
# 1
# 22

# %% [markdown]
# ##### 7-2-1 평당가격

# %%
labels = ["하락","유지","상승"]

# Create subplots: use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels, values=[6,2,17], name="9.13 대책"),
              1, 1)
fig.add_trace(go.Pie(labels=labels, values=[6,7,12], name="12.16 대책"),
              1, 2)
fig.add_trace(go.Pie(labels=labels, values=[2,1,22], name="6.17 대책"),
              1, 3)


fig.update_traces(hole=.4, hoverinfo="label+value+name")
fig.update_traces(textposition='inside', textinfo='percent+value+label')

fig.update_layout(
    title_text="<b>부동산 대책 이후 평당가격 변화</b>",
    annotations=[dict(text='9.13 대책', x=0.113, y=0.5, font_size=20, showarrow=False),
                 dict(text='12.16 대책', x=0.503, y=0.5, font_size=20, showarrow=False),
                 dict(text='6.17 대책', x=0.895, y=0.5, font_size=20, showarrow=False)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 9.13').sort_values('변화율_평당가격', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_평당가격', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>9.13 부동산 대책 이후 평당가격 변화율 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 12.16').sort_values('변화율_평당가격', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_평당가격', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>12.16 부동산 대책 이후 평당가격 변화 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 6.17').sort_values('변화율_평당가격', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_평당가격', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>6.17 부동산 대책 이후 평당가격 변화 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 하락
print(after_before_group.query('대책 == 9.13')["변화율_거래량"][after_before_group.query('대책 == 9.13')["변화율_거래량"] < 0].count())

# 유지
print(after_before_group.query('대책 == 9.13')["변화율_거래량"][after_before_group.query('대책 == 9.13')["변화율_거래량"] == 0].count())

# 상승
print(after_before_group.query('대책 == 9.13')["변화율_거래량"][after_before_group.query('대책 == 9.13')["변화율_거래량"] > 0].count())

# 하락
print(after_before_group.query('대책 == 12.16')["변화율_거래량"][after_before_group.query('대책 == 12.16')["변화율_거래량"] < 0].count())

# 유지
print(after_before_group.query('대책 == 12.16')["변화율_거래량"][after_before_group.query('대책 == 12.16')["변화율_거래량"] == 0].count())

# 상승
print(after_before_group.query('대책 == 12.16')["변화율_거래량"][after_before_group.query('대책 == 12.16')["변화율_거래량"] > 0].count())

# 하락
print(after_before_group.query('대책 == 6.17')["변화율_거래량"][after_before_group.query('대책 == 6.17')["변화율_거래량"] < 0].count())

# 유지
print(after_before_group.query('대책 == 6.17')["변화율_거래량"][after_before_group.query('대책 == 6.17')["변화율_거래량"] == 0].count())

# 상승
print(after_before_group.query('대책 == 6.17')["변화율_거래량"][after_before_group.query('대책 == 6.17')["변화율_거래량"] > 0].count())
# Out:
# 25
# 0
# 0
# 21
# 0
# 4
# 1
# 0
# 24

# %% [markdown]
# ##### 7-2-2 거래량

# %%
labels = ["하락", "유지", "상승"]

# Create subplots: use 'domain' type for Pie subplot
fig = make_subplots(rows=1, cols=3, specs=[[{'type':'domain'}, {'type':'domain'}, {'type':'domain'}]])
fig.add_trace(go.Pie(labels=labels, values=[25,0,0], name="9.13 대책"),
              1, 1)
fig.add_trace(go.Pie(labels=labels, values=[21,0,4], name="12.16 대책"),
              1, 2)
fig.add_trace(go.Pie(labels=labels, values=[1,0,24], name="6.17 대책"),
              1, 3)


fig.update_traces(hole=.4, hoverinfo="label+value+name")
fig.update_traces(textposition='inside', textinfo='percent+value+label')

fig.update_layout(
    title_text="<b>부동산 대책 이후 거래량 변화</b>",
    annotations=[dict(text='9.13 대책 거래량', x=0.107, y=0.5, font_size=15, showarrow=False),
                 dict(text='12.16 대책 거래량', x=0.50, y=0.5, font_size=15, showarrow=False),
                 dict(text='6.17 대책 거래량', x=0.895, y=0.5, font_size=15, showarrow=False)])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 9.13').sort_values('변화율_거래량', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_거래량', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>9.13 부동산 대책 이후 거래량 변화 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 12.16').sort_values('변화율_거래량', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_거래량', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>12.16 부동산 대책 이후 거래량 변화 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = after_before_group.query('대책 == 6.17').sort_values('변화율_거래량', ascending = False)
fig = px.bar(data, x = '구', y = '변화율_거래량', color = '구', text_auto='.1s')
fig.update_traces(textfont_size=12, textangle=0, textposition="outside")
fig.update_layout(template='simple_white', title_text="<b>6.17 부동산 대책 이후 거래량 변화 (단위:%)</b>")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
